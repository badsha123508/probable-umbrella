# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/badsha123508/probable-umbrella/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# I selected this lane because it focuses on helping content teams prioritize which pages should be reviewed first using observable search and engagement signals. Instead of relying on intuition, this approach uses data to identify pages that may benefit from refreshing, expanding, or monitoring. This supports better decision-making and aligns with the internship's goal of using machine learning to solve real-world problems.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which content pages should be prioritized for review?
#
# **Action:** The content team reviews the highest-ranked pages and decides whether to refresh, improve, expand, or continue monitoring them.
#
# **Cost of a wrong recommendation:** If an important page is overlooked, valuable search traffic and user engagement may continue to decline. If low-priority pages are selected instead, time and resources are wasted on pages with less potential impact.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)The starter dataset contains **30,000 content pages**, providing a substantial amount of data for analysis.
#
# On average, each page has **5,200.37 impressions** and **37.07 sessions** over a 90-day period, indicating meaningful variation in search visibility and user engagement.
#
# Additionally, **54.21% of the pages are marked as declining**, suggesting that many pages may benefit from review. These observations support my decision to explore the Refresh / Content Opportunity Scoring lane over the next seven weeks.
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd


# Load the starter dataset
df = pd.read_csv("probable-umbrella/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average 90-day sessions:", round(df["sessions_90d"].mean(), 2))

declining = (df["trend_direction"] == "down").mean() * 100
print("Percentage of declining pages:", round(declining, 2), "%")
# Out:
# Number of pages: 30000
# Average 90-day impressions: 5200.37
# Average 90-day sessions: 37.07
# Percentage of declining pages: 54.21 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
# ## What I Can and Can't Claim
#
# This project can identify observed patterns in historical search and engagement data that may help prioritize pages for review. The results are intended to support decision-making by highlighting pages that appear to have strong improvement opportunities.
#
# However, this work cannot prove that updating a page will cause higher search rankings, increased traffic, or improved engagement. It also cannot predict Google's algorithms or guarantee future performance. Any recommendations should be treated as decision-support rather than certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
